# %% [markdown]
# #  1.Download the dataset
# # import packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 2.load  the dataset into the tool

# %%
df=pd.read_csv('C:\\Users\\Gayathri\\Desktop\\abalone (1).csv')
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.shape
# Out:
# (4177, 9)

# %%
df['Age'] = df['Rings']+1.5

# %%
Age=1.5+df.Rings
df["Age"]=Age
df=df.rename(columns = {'Whole weight':'Whole_weight','Shucked weight': 'Shucked_weight','Viscera weight': 'Viscera_weight',
                            'Shell weight': 'Shell_weight'})
df=df.drop(columns=["Rings"],axis=1)
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight   Age
# 0         0.150  16.5
# 1         0.070   8.5
# 2         0.210  10.5
# 3         0.155  11.5
# 4         0.055   8.5

# %%
df.shape
# Out:
# (4177, 9)

# %% [markdown]
# # 3.perform below vistualizations

# %% [markdown]
# # Univariate Analysis

# %%
sns.displot(df["Sex"], color='red')

# %%
sns.histplot(y=df.Sex,color='pink')
# Out:
# <AxesSubplot:xlabel='Count', ylabel='Sex'>

# %%
sns.histplot(x=df.Age,color='yellow')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
sns.countplot(x=df.Sex)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# # Bi-variate Analysis

# %%
sns.barplot(x=df.Height,y=data.Sex)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Sex'>

# %%
sns.lineplot(x=df.Sex,y=df.Height, color='blue')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Height'>

# %%
sns.scatterplot(x=df.Sex,y=df.Height,color='darkorange')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Height'>

# %%
sns.pointplot(x=df.Sex, y=df.Height, color="green")
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Height'>

# %% [markdown]
# # Multi-variate Analysis

# %%
sns.pairplot(data=data[["Length","Diameter","Height","Age","Whole_weight","Shell_weight","Shucked_weight"]])

# %% [markdown]
# # 4.Perform Descriptive Statistics on the dataset

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole_weight  Shucked_weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera_weight  Shell_weight          Age
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831    11.433684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     2.500000
# ...

# %% [markdown]
# # 5. Check for Missing values and deal with them

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Age               0
# dtype: int64

# %% [markdown]
# # 6.Find the outliers and replace them outliers

# %%
outliers=df.quantile(q=(0.50,0.80))
outliers
# Out:
#      Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0.5   0.545     0.425   0.140        0.7995          0.3360           0.171
# 0.8   0.625     0.495   0.175        1.2393          0.5424           0.273
#
#      Shell_weight   Age
# 0.5        0.2340  10.5
# 0.8        0.3518  13.5

# %%
a = df.Age.quantile(0.25)
b = df.Age.quantile(0.75)
c = b - a
lower_limit = a - 1.5 * c
df.median(numeric_only=True)
# Out:
# Length             0.5450
# Diameter           0.4250
# Height             0.1400
# Whole_weight       0.7995
# Shucked_weight     0.3360
# Viscera_weight     0.1710
# Shell_weight       0.2340
# Age               10.5000
# dtype: float64

# %%
df['Age'] = np.where(df['Age'] < lower_limit, 5, df['Age'])
sns.boxplot(x=df.Age,showfliers = False)
# Out:
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# # 7.Check for Categorical columns and perform encoding.

# %%
from sklearn.preprocessing import LabelEncoder
lab = LabelEncoder()
df.Sex = lab.fit_transform(data.Sex)

# %%
df.head()
# Out:
#    Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera_weight  Shell_weight   Age
# 0          0.1010         0.150  16.5
# 1          0.0485         0.070   8.5
# 2          0.1415         0.210  10.5
# 3          0.1140         0.155  11.5
# 4          0.0395         0.055   8.5

# %% [markdown]
# # 8. Split the data into dependent and independent variables

# %%
y = df["Age"]
y.head()
# Out:
# 0    16.5
# 1     8.5
# 2    10.5
# 3    11.5
# 4     8.5
# Name: Age, dtype: float64

# %%
x=df.drop(columns=["Age"],axis=1)
x.head()
# Out:
#    Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera_weight  Shell_weight
# 0          0.1010         0.150
# 1          0.0485         0.070
# 2          0.1415         0.210
# 3          0.1140         0.155
# 4          0.0395         0.055

# %% [markdown]
# # 9.Scale the independent variables

# %%
from sklearn.preprocessing import scale
X_Scaled = pd.DataFrame(scale(x), columns=x.columns)
X_Scaled.head()
# Out:
#         Sex    Length  Diameter    Height  Whole_weight  Shucked_weight  \
# 0  1.151980 -0.574558 -0.432149 -1.064424     -0.641898       -0.607685
# 1  1.151980 -1.448986 -1.439929 -1.183978     -1.230277       -1.170910
# 2 -1.280690  0.050033  0.122130 -0.107991     -0.309469       -0.463500
# 3  1.151980 -0.699476 -0.432149 -0.347099     -0.637819       -0.648238
# 4 -0.064355 -1.615544 -1.540707 -1.423087     -1.272086       -1.215968
#
#    Viscera_weight  Shell_weight
# 0       -0.726212     -0.638217
# 1       -1.205221     -1.212987
# 2       -0.356690     -0.207139
# 3       -0.607600     -0.602294
# 4       -1.287337     -1.320757

# %% [markdown]
# # 10. Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 0)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (3132, 8)
# (3132,)

# %%
print(x_test.shape)
print(y_test.shape)
# Out:
# (1045, 8)
# (1045,)

# %%
x_train.head()
# Out:
#       Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 940     1   0.460     0.345   0.105        0.4490          0.1960
# 2688    2   0.630     0.465   0.150        1.0270          0.5370
# 1948    2   0.635     0.515   0.165        1.2290          0.5055
# 713     2   0.355     0.265   0.085        0.2010          0.0690
# 3743    0   0.705     0.555   0.195        1.7525          0.7105
#
#       Viscera_weight  Shell_weight
# 940           0.0945        0.1265
# 2688          0.1880        0.1760
# 1948          0.2975        0.3535
# 713           0.0530        0.0695
# 3743          0.4215        0.5160

# %%
y_train.head()
# Out:
# 940      8.5
# 2688     9.5
# 1948    11.5
# 713      9.5
# 3743    13.5
# Name: Age, dtype: float64

# %%
x_test.head()
# Out:
#       Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 668     2   0.550     0.425   0.155        0.9175          0.2775
# 1580    1   0.500     0.400   0.120        0.6160          0.2610
# 3784    2   0.620     0.480   0.155        1.2555          0.5270
# 463     1   0.220     0.165   0.055        0.0545          0.0215
# 2615    2   0.645     0.500   0.175        1.5105          0.6735
#
#       Viscera_weight  Shell_weight
# 668           0.2430        0.3350
# 1580          0.1430        0.1935
# 3784          0.3740        0.3175
# 463           0.0120        0.0200
# 2615          0.3755        0.3775

# %%
y_test.head()
# Out:
# 668     14.5
# 1580     9.5
# 3784    12.5
# 463      6.5
# 2615    13.5
# Name: Age, dtype: float64

# %% [markdown]
# # 11. Build the Model

# %% [markdown]
# # decision tree classifies

# %%
y = df["Sex"]
y.head()
# Out:
# 0    2
# 1    2
# 2    0
# 3    2
# 4    1
# Name: Sex, dtype: int32

# %%
x=df.drop(columns=["Sex"],axis=1)
x.head()
# Out:
#    Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight   Age
# 0         0.150  16.5
# 1         0.070   8.5
# 2         0.210  10.5
# 3         0.155  11.5
# 4         0.055   8.5

# %%
from sklearn.preprocessing import scale
X_Scaled = pd.DataFrame(scale(x), columns=x.columns)
X_Scaled.head()
# Out:
#      Length  Diameter    Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0 -0.574558 -0.432149 -1.064424     -0.641898       -0.607685       -0.726212
# 1 -1.448986 -1.439929 -1.183978     -1.230277       -1.170910       -1.205221
# 2  0.050033  0.122130 -0.107991     -0.309469       -0.463500       -0.356690
# 3 -0.699476 -0.432149 -0.347099     -0.637819       -0.648238       -0.607600
# 4 -1.615544 -1.540707 -1.423087     -1.272086       -1.215968       -1.287337
#
#    Shell_weight       Age
# 0     -0.638217  1.573597
# 1     -1.212987 -0.912553
# 2     -0.207139 -0.291016
# 3     -0.602294  0.019753
# 4     -1.320757 -0.912553

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 0)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(max_depth=4,splitter='best',criterion='entropy')

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
y_predict= model.predict(x_test)
y_predict
# Out:
# array([2, 1, 0, ..., 2, 0, 2])

# %%
y_predict_train = model.predict(x_train)
y_predict_train
# Out:
# array([1, 2, 0, ..., 2, 2, 1])

# %% [markdown]
# # Linear Regression

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression() 
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([0.87945877, 0.99127461, 0.89235449, ..., 1.01800626, 0.96971064,
#        0.98661502])

# %%
y_test
# Out:
# 668     2
# 1580    1
# 3784    2
# 463     1
# 2615    2
#        ..
# 1420    0
# 2104    0
# 3382    2
# 3424    2
# 1160    0
# Name: Sex, Length: 1045, dtype: int32

# %%
Age=pd.DataFrame({'Actual_y_value':y_test,'Predicted_y_value':y_pred})
Age.head(10)
# Out:
#       Actual_y_value  Predicted_y_value
# 668                2           0.879459
# 1580               1           0.991275
# 3784               2           0.892354
# 463                1           1.170177
# 2615               2           1.025429
# 1399               0           0.952101
# 2054               2           1.129616
# 2058               2           0.993958
# 217                1           1.067176
# 1931               2           0.889279

# %%
y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)
from sklearn.metrics import mean_absolute_error, mean_squared_error
s = mean_squared_error(y_train, y_train_pred)
print('Mean Squared error of training set :%2f'%s)

p = mean_squared_error(y_test, y_test_pred)
print('Mean Squared error of testing set :%2f'%p)
# Out:
# Mean Squared error of training set :0.675899
# Mean Squared error of testing set :0.648133

# %% [markdown]
# # Random Forest Classifier

# %%
y = df["Sex"]
y.head()
# Out:
# 0    2
# 1    2
# 2    0
# 3    2
# 4    1
# Name: Sex, dtype: int32

# %%
x=df.drop(columns=["Sex"],axis=1)
x.head()
# Out:
#    Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight   Age
# 0         0.150  16.5
# 1         0.070   8.5
# 2         0.210  10.5
# 3         0.155  11.5
# 4         0.055   8.5

# %%
from sklearn.preprocessing import scale
X_Scaled = pd.DataFrame(scale(x), columns=x.columns)
X_Scaled.head()
# Out:
#      Length  Diameter    Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0 -0.574558 -0.432149 -1.064424     -0.641898       -0.607685       -0.726212
# 1 -1.448986 -1.439929 -1.183978     -1.230277       -1.170910       -1.205221
# 2  0.050033  0.122130 -0.107991     -0.309469       -0.463500       -0.356690
# 3 -0.699476 -0.432149 -0.347099     -0.637819       -0.648238       -0.607600
# 4 -1.615544 -1.540707 -1.423087     -1.272086       -1.215968       -1.287337
#
#    Shell_weight       Age
# 0     -0.638217  1.573597
# 1     -1.212987 -0.912553
# 2     -0.207139 -0.291016
# 3     -0.602294  0.019753
# 4     -1.320757 -0.912553

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state = 0)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=10,criterion='entropy')

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10)

# %%
y_predict = model.predict(x_test)
y_predict
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
y_predict_train = model.predict(x_train)
y_predict_train
# Out:
# array([1, 2, 0, ..., 2, 0, 1])

# %% [markdown]
# # 12. Train the Model

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
print('Training accuracy: ',accuracy_score(y_train,y_predict_train))
# Out:
# Training accuracy:  0.9802043422733078

# %% [markdown]
# # 13. Test the Model

# %%
print('Testing accuracy: ',accuracy_score(y_test,y_predict))
# Out:
# Testing accuracy:  0.5464114832535886

# %% [markdown]
# # 14. Measure the performance using Metrics.

# %%
pd.crosstab(y_test,y_predict)
# Out:
# col_0    0    1    2
# Sex
# 0      156   37  123
# 1       44  266   49
# 2      152   69  149

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.44      0.49      0.47       316
#            1       0.72      0.74      0.73       359
#            2       0.46      0.40      0.43       370
#
#     accuracy                           0.55      1045
#    macro avg       0.54      0.55      0.54      1045
# weighted avg       0.54      0.55      0.54      1045
